# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import math
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
import re

# %matplotlib inline

# %%
data = pd.read_csv('NewsArticles.csv')

# %%
# The data parsed in with extra blank columns due to encoding formatting.
data.head(10)
# Out:
#    article_id publish_date                                article_source_link  \
# 0           1       2/7/17  http://abcnews.go.com/Politics/pence-break-tie...
# 1           2       2/7/17  http://abcnews.go.com/Politics/wireStory/melan...
# 2           3       2/7/17  http://abcnews.go.com/Politics/wireStory/trump...
# 3           4       2/7/17  http://abcnews.go.com/Politics/appeals-court-d...
# 4           5       2/7/17  http://abcnews.go.com/US/23-states-winter-weat...
# 5           6       2/7/17  http://abcnews.go.com/International/wireStory/...
# 6           7       2/7/17  http://abcnews.go.com/Politics/trumps-labor-se...
# 7           8       2/7/17  http://abcnews.go.com/International/wireStory/...
# 8           9       2/7/17  http://abcnews.go.com/International/wireStory/...
# 9          10       2/7/17  http://abcnews.go.com/US/multi-state-manhunt-s...
#
#                                                title subtitle  \
# 0  Betsy DeVos Confirmed as Education Secretary, ...      NaN
# 1  Melania Trump Says White House Could Mean Mill...      NaN
# 2  As Trump Fears Fraud, GOP Eliminates Election ...      NaN
# 3  Appeals Court to Decide on Challenge to Trump'...      NaN
# 4  At Least 4 Tornadoes Reported in Southeast Lou...      NaN
# 5  Mother of Backpacker Slain in Australia Critic...      NaN
# 6  Trump's Labor Secretary Pick Andrew Puzder Adm...      NaN
# 7           Iran's Top Leader Mocks 'Newcomer' Trump      NaN
# 8  EU to Britain: Pay Up for What You Ordered Bef...      NaN
# 9  Multi-State Manhunt in Southeast Intensifies f...      NaN
#
#                                                 text Unnamed: 6 Unnamed: 7  \
# 0  Michigan billionaire education activist Betsy ...        NaN        NaN
# 1  First lady Melania Trump has said little about...        NaN        NaN
# 2  A House committee voted on Tuesday to eliminat...        NaN        NaN
# 3  This afternoon, three federal judges from the ...        NaN        NaN
# 4  At least four tornadoes touched down in Louisi...        NaN        NaN
# 5  The mother of a backpacker slain in an Austral...        NaN        NaN
# 6  Donald Trump's pick for labor secretary, Andre...        NaN        NaN
# 7  Iran's supreme leader said Tuesday that "newco...        NaN        NaN
# 8  The European Union is warning Britain that any...        NaN        NaN
# 9  A manhunt is intensifying in the Southeast for...        NaN        NaN
#
#   Unnamed: 8 Unnamed: 9     ...      Unnamed: 134 Unnamed: 135 Unnamed: 136  \
# 0        NaN        NaN     ...               NaN          NaN          NaN
# 1        NaN        NaN     ...               NaN          NaN          NaN
# 2        NaN        NaN     ...               NaN          NaN          NaN
# 3        NaN        NaN     ...               NaN          NaN          NaN
# 4        NaN        NaN     ...               NaN          NaN          NaN
# 5        NaN        NaN     ...               NaN          NaN          NaN
# 6        NaN        NaN     ...               NaN          NaN          NaN
# 7        NaN        NaN     ...               NaN          NaN          NaN
# 8        NaN        NaN     ...               NaN          NaN          NaN
# 9        NaN        NaN     ...               NaN          NaN          NaN
#
#   Unnamed: 137 Unnamed: 138 Unnamed: 139 Unnamed: 140 Unnamed: 141  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN          NaN
# 6          NaN          NaN          NaN          NaN          NaN
# 7          NaN          NaN          NaN          NaN          NaN
# 8          NaN          NaN          NaN          NaN          NaN
# 9          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 142 Unnamed: 143
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
# 5          NaN          NaN
# 6          NaN          NaN
# 7          NaN          NaN
# 8          NaN          NaN
# 9          NaN          NaN
#
# [10 rows x 144 columns]

# %%
# All 'Unnamed' columns can be dropped.
data.columns
# Out:
# Index(['article_id', 'publish_date', 'article_source_link', 'title',
#        'subtitle', 'text', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9',
#        ...
#        'Unnamed: 134', 'Unnamed: 135', 'Unnamed: 136', 'Unnamed: 137',
#        'Unnamed: 138', 'Unnamed: 139', 'Unnamed: 140', 'Unnamed: 141',
#        'Unnamed: 142', 'Unnamed: 143'],
#       dtype='object', length=144)

# %%
# Keeping what we need, storing to df. 
df = pd.DataFrame()
cols_keep = ['article_id', 'publish_date', 'article_source_link', 'title',
       'subtitle', 'text']

for col in cols_keep:
    df[col] = data[col]

# %%
df.head()
# Out:
#    article_id publish_date                                article_source_link  \
# 0           1       2/7/17  http://abcnews.go.com/Politics/pence-break-tie...
# 1           2       2/7/17  http://abcnews.go.com/Politics/wireStory/melan...
# 2           3       2/7/17  http://abcnews.go.com/Politics/wireStory/trump...
# 3           4       2/7/17  http://abcnews.go.com/Politics/appeals-court-d...
# 4           5       2/7/17  http://abcnews.go.com/US/23-states-winter-weat...
#
#                                                title subtitle  \
# 0  Betsy DeVos Confirmed as Education Secretary, ...      NaN
# 1  Melania Trump Says White House Could Mean Mill...      NaN
# 2  As Trump Fears Fraud, GOP Eliminates Election ...      NaN
# 3  Appeals Court to Decide on Challenge to Trump'...      NaN
# 4  At Least 4 Tornadoes Reported in Southeast Lou...      NaN
#
#                                                 text
# 0  Michigan billionaire education activist Betsy ...
# 1  First lady Melania Trump has said little about...
# 2  A House committee voted on Tuesday to eliminat...
# 3  This afternoon, three federal judges from the ...
# 4  At least four tornadoes touched down in Louisi...

# %%
# Lets take a look at the first article by ABC News
print(df['text'][0])
# Out:
# Michigan billionaire education activist Betsy DeVos was confirmed today to serve as the secretary of education in President Trump's administration, after Vice President Mike Pence cast a tie-breaking vote in the Senate. The Senate voted on DeVos"?highly contentious nomination this afternoon, and the tally was split evenly, requiring Pence to use his authority as president of the upper chamber of Congress to break the impasse. This was the first time that a vice president has broken a tie to confirm a Cabinet nominee. Pence read the vote count 50-50 and then voted himself, rendering the tally 51-50. The day before the vote, Democrats staged a 24-hour marathon of speeches, with more than 30 lawmakers taking to the floor to urge at least one additional Republican to vote against DeVos and block her confirmation. "It is hard to imagine a worse choice,"?Sen. Elizabeth Warren, D-Mass., said before she read letters from constituents urging her to vote no. DeVos stirred up vehement opposition from teachers"?unions and all 48 Senate Democrats. Many cited concerns about her support of school vouchers, which critics believe will weaken public schools, and her lack of experience, since she never attended or worked in the public education system. Others cited her lack of familiarity with a landmark law protecting the education needs of disabled children.     She was panned for a gaffe during her confirmation hearing, when she hedged on an answer about guns in schools by saying they might be needed in states like Wyoming to defend against "potential grizzlies."?DeVos' nomination drew above-average negative reactions from the public, with voters flooding Senate phone lines and email accounts in recent weeks. Sen. Chris Van Hollen, D-Md., said his office received 14,000 calls about DeVos. In addition to the entire Democratic caucus, two moderate Republicans, Sens. Susan Collins of Maine and Lisa Murkowski of Alaska announced they would not support DeVos. During a speech announcing her opposition, Collins said DeVos"?focus on charters and vouchers "raises the question of whether or not she fully appreciates that the secretary of education's primary focus must be on helping states and communities, parents, teachers, school board members and administrators strengthen our public schools."?Before the confirmation vote, the Senate Health, Education, Labor and Pensions Committee voted along party lines, 12-11, to refer DeVos"?nomination to the full Senate. ABC News"?Morgan Winsor contributed to this report.

# %%
# Going to start with a quick latent semantic analysis of just the article text.
corpus = df['text']

# %%
# Number of documents in the corpus
len(corpus)
# Out:
# 3824

# %%
corpus = corpus.astype(str)

# %%
# Convert all text to lower-case
corpus = [x.lower() for x in corpus]

# %%
print(corpus[0])
# Out:
# michigan billionaire education activist betsy devos was confirmed today to serve as the secretary of education in president trump's administration, after vice president mike pence cast a tie-breaking vote in the senate. the senate voted on devos"?highly contentious nomination this afternoon, and the tally was split evenly, requiring pence to use his authority as president of the upper chamber of congress to break the impasse. this was the first time that a vice president has broken a tie to confirm a cabinet nominee. pence read the vote count 50-50 and then voted himself, rendering the tally 51-50. the day before the vote, democrats staged a 24-hour marathon of speeches, with more than 30 lawmakers taking to the floor to urge at least one additional republican to vote against devos and block her confirmation. "it is hard to imagine a worse choice,"?sen. elizabeth warren, d-mass., said before she read letters from constituents urging her to vote no. devos stirred up vehement opposition from teachers"?unions and all 48 senate democrats. many cited concerns about her support of school vouchers, which critics believe will weaken public schools, and her lack of experience, since she never attended or worked in the public education system. others cited her lack of familiarity with a landmark law protecting the education needs of disabled children.     she was panned for a gaffe during her confirmation hearing, when she hedged on an answer about guns in schools by saying they might be needed in states like wyoming to defend against "potential grizzlies."?devos' nomination drew above-average negative reactions from the public, with voters flooding senate phone lines and email accounts in recent weeks. sen. chris van hollen, d-md., said his office received 14,000 calls about devos. in addition to the entire democratic caucus, two moderate republicans, sens. susan collins of maine and lisa murkowski of alaska announced they would not support devos. during a speech announcing her opposition, collins said devos"?focus on charters and vouchers "raises the question of whether or not she fully appreciates that the secretary of education's primary focus must be on helping states and communities, parents, teachers, school board members and administrators strengthen our public schools."?before the confirmation vote, the senate health, education, labor and pensions committee voted along party lines, 12-11, to refer devos"?nomination to the full senate. abc news"?morgan winsor contributed to this report.

# %%
# Import NTLK stopset
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jsche4/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# This cell will be used to add new exclusion words to the stopset before and/or after model testing.
# Note: Most of the words below were added over the course of numerous output testing efforts.

stopset = set(stopwords.words('english'))

stopset.update(['facebook','whatsapp','digg','reddit','newsvine','permalink','tumblr','linkedin','http','dw','com'])

# %%
# Define the vectorizer model
vectorizer = TfidfVectorizer(stop_words=stopset, use_idf=True, ngram_range=(2, 4),smooth_idf=True)

# Fit the corpus data
X = vectorizer.fit_transform(corpus)

# %%
# First article vectorized
print(X[0])
# Out:
#   (0, 1654612)	0.0368487587678
#   (0, 352153)	0.0368487587678
#   (0, 848000)	0.0368487587678
#   (0, 102445)	0.0368487587678
#   (0, 340347)	0.0295069368516
#   (0, 770820)	0.035102546157
#   (0, 595129)	0.0338635885925
#   (0, 2697259)	0.0338635885925
#   (0, 2397214)	0.035102546157
#   (0, 2366111)	0.0629069935165
#   (0, 848565)	0.0368487587678
#   (0, 2033749)	0.0163211854688
#   (0, 2744989)	0.0149115546552
#   (0, 118875)	0.0368487587678
#   (0, 2844337)	0.0350351849327
#   (0, 2031463)	0.0214156528448
#   (0, 1659726)	0.0209618977437
#   (0, 1926173)	0.0338635885925
#   (0, 451412)	0.0338635885925
#   (0, 2681722)	0.0321173759817
#   (0, 383519)	0.0321173759817
#   (0, 2862626)	0.0598348165394
#   (0, 2386065)	0.0368487587678
#   (0, 2386211)	0.0321173759817
#   (0, 2863243)	0.035102546157
#   :	:
#   (0, 2558388)	0.0368487587678
#   (0, 2093894)	0.0368487587678
#   (0, 2351944)	0.0368487587678
#   (0, 594275)	0.0368487587678
#   (0, 2862632)	0.0368487587678
#   (0, 2385587)	0.0368487587678
#   (0, 1203416)	0.035102546157
#   (0, 848398)	0.0368487587678
#   (0, 1446286)	0.0368487587678
#   (0, 1927824)	0.0368487587678
#   (0, 564167)	0.0368487587678
#   (0, 2863134)	0.0368487587678
#   (0, 169715)	0.0368487587678
#   (0, 1909889)	0.0368487587678
#   (0, 1524975)	0.0368487587678
#   (0, 10376)	0.0368487587678
#   (0, 9540)	0.0368487587678
#   (0, 2157925)	0.0368487587678
#   (0, 770898)	0.0368487587678
#   (0, 1785033)	0.0368487587678
#   (0, 1084748)	0.0368487587678
#   (0, 2385160)	0.0368487587678
#   (0, 73789)	0.0368487587678
#   (0, 1774041)	0.0368487587678
#   (0, 1700010)	0.035102546157

# %%
# The current shape is (documents, terms)
X.shape
# Out:
# (3824, 3012078)

# %%
# Defining the TruncatedSVD model

# Params: n_components=100 for LSA per sk-learn doc, n_iter=5 (default, and should be adjusted during testing) 
lsa = TruncatedSVD(n_components=100, n_iter=5)

# Fit the model
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=100, n_iter=5,
#        random_state=None, tol=0.0)

# %%
import sys
print (sys.version)
# Out:
# 3.6.0 |Anaconda custom (x86_64)| (default, Dec 23 2016, 13:19:00)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]

# %%
# Convert the SVD results from numerical representation, back to their appropriate word text form.
# Iterates over the enumeration of matrix components, for each: zips the terms to components, sorts them, then prints. 
terms = vectorizer.get_feature_names()
for i, comp in enumerate(lsa.components_): 
    termsInComp = zip (terms,comp)
    sortedTerms =  sorted(termsInComp, key=lambda x: x[1], reverse=True) [:10]
    print("Concept %d:" % i )
    for term in sortedTerms:
        print(term[0])
    print (" ")
# Out:
# Concept 0:
# awards coverage
# awards coverage sent
# awards coverage sent right
# bits industry
# bits industry awards
# bits industry awards coverage
# celebrity news
# celebrity news hilarious
# celebrity news hilarious late
# coverage sent
#
# Concept 1:
# north korea
# kim jong
# north korean
# jong nam
# kim jong nam
# south korea
# kuala lumpur
# white house
# jong un
# kim jong un
#
# Concept 2:
# white house
# mr trump
# donald trump
# trump first
# president donald
# president donald trump
# intelligence committee
# first 100
# first 100 days
# 100 days
#
# Concept 3:
# provisional suspensions
# russian cross
# russian cross country
# cross country
# alexey petukhov
# evgenia shapovalova
# ivanova evgenia
# ivanova evgenia shapovalova
# julia ivanova
# julia ivanova evgenia
#
# Concept 4:
# trump first 100 days
# trump first 100
# first 100 days
# first 100
# 100 days
# trump first
# 100 days impact
# days impact
# first 100 days impact
# huffington post
#
# Concept 5:
# orly airport
# car later found
# die allah
# car later
# south paris
# ben belgacem
# later found
# put gun
# garges les
# garges les gonesse
#
# Concept 6:
# north korea
# south korea
# al jazeera
# prime minister
# foreign minister
# european union
# human rights
# china daily
# united states
# source al
#
# Concept 7:
# jong nam
# kim jong
# kim jong nam
# north korean
# kuala lumpur
# prime minister
# nerve agent
# european union
# introduced temporary
# half brother
#
# Concept 8:
# north korea
# south korea
# trump campaign
# mr sessions
# armed services
# armed services committee
# services committee
# introduced temporary
# attorney general
# confirmation hearing
#
# Concept 9:
# garda station
# mr sessions
# trump campaign
# armed services
# armed services committee
# services committee
# attorney general
# al jazeera
# garda confidential
# line 1800
#
# Concept 10:
# garda station
# garda confidential
# line 1800
# confidential line
# confidential line 1800
# garda confidential line
# garda confidential line 1800
# 1800 666
# 1800 666 111
# 666 111
#
# Concept 11:
# china daily
# china daily european
# daily european
# china daily european weekly
# daily european weekly
# european weekly
# chinadaily cn
# belt road
# daily european weekly 01
# european weekly 01
#
# Concept 12:
# executive order
# al jazeera
# mr trump
# travel ban
# united states
# source al
# source al jazeera
# al jazeera news
# jazeera news
# source al jazeera news
#
# Concept 13:
# mr trump
# executive order
# mrs may
# travel ban
# article 50
# theresa may
# northern ireland
# independence referendum
# restraining order
# new order
#
# Concept 14:
# new york
# executive order
# view comments
# travel ban
# new york city
# york city
# mr trump
# daily news
# restraining order
# new order
#
# Concept 15:
# new york
# everyone talking learn
# last watch
# last watch viral
# last watch viral video
# talking learn
# video everyone
# video everyone talking
# video everyone talking learn
# viral video everyone
#
# Concept 16:
# president park
# south korea
# corruption scandal
# choi soon
# choi soon sil
# soon sil
# jae yong
# lee jae
# lee jae yong
# geun hye
#
# Concept 17:
# intelligence committee
# rock roll
# north korea
# mrs may
# american spirit
# health insurance
# white house
# secret service
# chuck berry
# every american
#
# Concept 18:
# view comments
# winter universiade
# rock roll
# russian foreign
# moscow february
# february tass
# chuck berry
# foreign minister
# moscow february tass
# foreign ministry
#
# Concept 19:
# view comments
# le pen
# de lima
# health care
# white house
# geert wilders
# march 20
# secret service
# care act
# ryan mcbride
#
# Concept 20:
# rock roll
# chuck berry
# rock roll music
# roll music
# johnny goode
# berry died
# chuck berry died
# rolling stones
# charles county
# st charles
#
# Concept 21:
# rock roll
# winter universiade
# chuck berry
# view comments
# bronze medals
# al jazeera
# de lima
# rock roll music
# roll music
# geert wilders
#
# Concept 22:
# mr trump
# tax returns
# income tax
# tax rate
# two pages
# trump paid
# tax return
# federal income
# david cay
# cay johnston
#
# Concept 23:
# de lima
# executive order
# al jazeera
# view comments
# restraining order
# stock trades
# trump administration
# travel ban
# attorney general
# intelligence committee
#
# Concept 24:
# geert wilders
# far right
# mark rutte
# asylum requests
# minister mark
# minister mark rutte
# prime minister mark
# prime minister mark rutte
# russian foreign
# foreign minister
#
# Concept 25:
# de lima
# asylum requests
# applications percent
# asylum seekers
# view comments
# follow applications
# requests 2016
# suspected far
# suspected far right
# germany 2016
#
# Concept 26:
# intelligence committee
# climate change
# tax returns
# mr trump
# house intelligence committee
# house intelligence
# nunes said
# trump tower
# de lima
# senate intelligence
#
# Concept 27:
# climate change
# health care
# care act
# de lima
# obama era
# clean power
# clean power plan
# power plan
# global warming
# environmental groups
#
# Concept 28:
# de lima
# mr trump
# health care
# care act
# political persecution
# de lima also
# de lima also led
# de lima previously
# lima also
# lima also led
#
# Concept 29:
# leicester city
# premier league
# champions league
# media playback
# media playback supported
# media playback supported device
# playback supported
# playback supported device
# supported device
# claudio ranieri
#
# Concept 30:
# de lima
# secret service
# white house
# tax returns
# abc news
# new york
# secret service said
# bike rack
# executive order
# house fence
#
# Concept 31:
# health care
# tax returns
# care act
# affordable care
# affordable care act
# executive order
# income tax
# health insurance
# restraining order
# freedom caucus
#
# Concept 32:
# bus ireann
# mr kenny
# coast guard
# fine gael
# pic twitter
# new york
# mr ross
# enda kenny
# parliamentary party
# fianna il
#
# Concept 33:
# 2016 target
# 2015 target
# target one
# knife attack
# 2015 target one
# wounded knife
# wounded knife attack
# death penalty
# target two
# wounded shooting
#
# Concept 34:
# le pen
# prime minister
# party freedom
# twitter google
# google stumble
# send twitter
# send twitter google
# send twitter google stumble
# twitter google stumble
# wilders party
#
# Concept 35:
# death penalty
# mr duterte
# back death
# back death penalty
# bus ireann
# drug war
# bring back death
# bring back death penalty
# death penalty drug
# death penalty drug related
#
# Concept 36:
# bus ireann
# 2016 target
# 2015 target
# target one
# mr ross
# iarnr ireann
# knife attack
# 2015 target one
# dublin bus
# wounded knife
#
# Concept 37:
# bus ireann
# st petersburg
# st isaac
# secret service
# white house
# isaac cathedral
# st isaac cathedral
# mr ross
# iarnr ireann
# orthodox church
#
# Concept 38:
# coast guard
# st petersburg
# st isaac
# black box
# crew members
# isaac cathedral
# st isaac cathedral
# mark duffy
# paul ormsby
# orthodox church
#
# Concept 39:
# coast guard
# 2016 target
# 2015 target
# target one
# russian foreign
# white house
# black box
# iraqi forces
# foreign minister
# executive order
#
# Concept 40:
# mr kenny
# fine gael
# northern ireland
# st petersburg
# parliamentary party
# enda kenny
# sgt mccabe
# st isaac
# kenny said
# terms reference
#
# Concept 41:
# st petersburg
# st isaac
# isaac cathedral
# st isaac cathedral
# mr kenny
# russian foreign
# foreign minister
# mr bailey
# human rights
# march 20
#
# Concept 42:
# le pen
# abc news
# iraqi forces
# march 20
# new york
# peace treaty
# kuril islands
# marine le
# marine le pen
# new york city
#
# Concept 43:
# benghazi defence
# benghazi defence brigades
# defence brigades
# ras lanuf
# es sider
# libya oil
# peace treaty
# libya oil production
# kuril islands
# oil ports
#
# Concept 44:
# white house
# new york
# la la
# la la land
# la land
# abc news
# musk said
# mr musk
# around moon
# deep space
#
# Concept 45:
# le pen
# white house
# security council
# marine le
# marine le pen
# foreign ministry
# musk said
# mr musk
# francois fillon
# fake jobs
#
# Concept 46:
# intelligence committee
# al jazeera
# naval task
# le pen
# naval task force
# admiral kuznetsov
# mr flynn
# aircraft carrier
# pyotr veliky
# house intelligence
#
# Concept 47:
# new york
# russian foreign
# foreign ministry
# russian foreign ministry
# st petersburg
# new york city
# york city
# security council
# vitaly churkin
# mr trump
#
# Concept 48:
# secret service
# ukrainian military
# contact group
# mr trump
# year old
# northern ireland
# however ukrainian
# however ukrainian military
# luganskoye signalnoye
# march 20
#
# Concept 49:
# secret service
# human rights
# impact learn
# mr trump
# mr sessions
# 100 days impact learn
# days impact learn
# climate change
# la la
# la la land
#
# Concept 50:
# european union
# muslim women
# kara murza
# philosophical religious
# political philosophical
# political philosophical religious
# west bank
# ukrainian military
# court justice
# religious symbols
#
# Concept 51:
# secret service
# al bab
# dmitry peskov
# spokesman dmitry peskov
# spokesman dmitry
# al jazeera
# russian president
# belt road
# intelligence committee
# peskov said
#
# Concept 52:
# mr bailey
# two state
# emergency spillway
# google stumble
# send twitter
# send twitter google
# send twitter google stumble
# twitter google stumble
# twitter google
# state solution
# Concept 53:
# la la
# la la land
# la land
# ukrainian military
# contact group
# south africa
# lavrov said
# best picture
# however ukrainian
# however ukrainian military
#
# Concept 54:
# al bab
# ukrainian military
# syrian government
# contact group
# impact learn
# 100 days impact learn
# days impact learn
# march 20
# however ukrainian
# however ukrainian military
#
# Concept 55:
# year old
# mr trump
# white house
# pic twitter
# anti doping
# ms mclaughlin
# tennis player
# tennis tournament
# independence referendum
# summer olympics
#
# Concept 56:
# northern ireland
# mr kenny
# march 20
# mr brokenshire
# vladimir putin
# president vladimir
# president vladimir putin
# le pen
# climate change
# sioux tribe
#
# Concept 57:
# aerospace force
# national insurance
# vitaly churkin
# mr trump
# press office
# nuclear weapons
# combat readiness
# human rights
# mr bailey
# moscow february
#
# Concept 58:
# la la
# la la land
# la land
# mr bailey
# le pen
# white house
# best picture
# nuclear weapons
# northern ireland
# intelligence committee
#
# Concept 59:
# south africa
# al bab
# national insurance
# northern ireland
# mr hammond
# self employed
# twitter google
# google stumble
# send twitter
# send twitter google
#
# Concept 60:
# year old
# article 50
# march 20
# credit rating
# human rights
# la la
# la la land
# la land
# mrs may
# abc news
#
# Concept 61:
# kara murza
# derbyshire programme
# victoria derbyshire programme
# victoria derbyshire
# 00 11 00 bbc
# 00 bbc two bbc
# 00 11
# 09 00 11
# 09 00 11 00
# 11 00 bbc
#
# Concept 62:
# south africa
# mr bailey
# le pen
# pic twitter
# climate change
# world cup
# south african
# mr flynn
# mr brokenshire
# scott pruitt
#
# Concept 63:
# kara murza
# twitter google
# google stumble
# send twitter
# send twitter google
# send twitter google stumble
# twitter google stumble
# kuril islands
# vitaly churkin
# peace treaty
#
# Concept 64:
# derbyshire programme
# victoria derbyshire programme
# victoria derbyshire
# march 20
# bbc news channel
# 00 11
# 00 bbc two bbc
# 00 11 00
# 00 11 00 bbc
# 09 00 11
#
# Concept 65:
# human rights
# bbc trending
# article 50
# intelligence committee
# google stumble
# send twitter
# send twitter google
# send twitter google stumble
# twitter google stumble
# twitter google
#
# Concept 66:
# credit rating
# mr bailey
# white house
# national insurance
# kara murza
# south africa
# north korea
# al jazeera
# march 20
# mr hammond
#
# Concept 67:
# abc news
# human rights
# anti doping
# march 20
# standing rock
# sioux tribe
# told abc news
# derbyshire programme
# victoria derbyshire programme
# told abc
#
# Concept 68:
# al jazeera
# anti doping
# world championship
# north korean
# pic twitter
# emergency spillway
# oroville dam
# attorney general
# le pen
# ibu world
#
# Concept 69:
# le pen
# al bab
# two state
# west bank
# russian banks
# state solution
# two state solution
# national bank ukraine
# bank ukraine
# islamic state
#
# Concept 70:
# national insurance
# ms shortall
# mr hammond
# south sudan
# ms mclaughlin
# self employed
# mr webster
# bbc trending
# emergency spillway
# prime minister
#
# Concept 71:
# mr bailey
# south sudan
# south africa
# pic twitter
# central bank
# interest rate
# federal reserve
# credit rating
# mr kenny
# body shop
#
# Concept 72:
# south sudan
# mr bailey
# kara murza
# lavrov said
# northern ireland
# climate change
# moscow march
# high speed
# french authorities
# du plantier
#
# Concept 73:
# ms mclaughlin
# scott pruitt
# human rights
# white house
# mr kenny
# trump said
# credit rating
# deputy foreign
# deputy foreign minister
# ministry said
#
# Concept 74:
# march 20
# pic twitter
# bbc trending
# deputy foreign
# deputy foreign minister
# fianna il
# garda commissioner
# kara murza
# abc news
# garda ªoch
#
# Concept 75:
# mr bailey
# al bab
# new york
# weird news
# two state
# west bank
# north korea
# attorney general
# mr sessions
# state solution
#
# Concept 76:
# mr bailey
# le pen
# new zealand
# south africa
# al waer
# high speed
# emergency spillway
# national guard
# united states
# mulvaney said
#
# Concept 77:
# white house
# pic twitter
# security council
# last year
# album year
# ballistic missile
# emergencies services
# moscow march
# peskov said
# vitaly churkin
#
# Concept 78:
# human rights
# abc news
# moscow march
# russian banks
# mr trump
# bank ukraine
# national insurance
# national bank ukraine
# national bank
# emergencies services
#
# Concept 79:
# south sudan
# emergency spillway
# pic twitter
# article 50
# oroville dam
# lavrov said
# man arrested
# water resources
# file prepared
# file prepared director
#
# Concept 80:
# mr bailey
# ministry said
# emergency spillway
# trump said
# human rights
# fake news
# le pen
# kara murza
# oroville dam
# foreign ministry
#
# Concept 81:
# john god
# st john god
# st john
# south sudan
# vice president
# mr bailey
# anti doping
# president vladimir
# president vladimir putin
# ms shortall
#
# Concept 82:
# south sudan
# mr bailey
# white house
# kara murza
# south africa
# donald trump
# syrian government
# supreme court
# mr trump
# news agency
#
# Concept 83:
# climate change
# pic twitter
# ministry said
# world cup
# article 50
# mrs may
# south africa
# foreign ministry
# al qaeda
# new zealand
#
# Concept 84:
# south sudan
# prime minister
# russian banks
# deputy foreign
# executive order
# deputy foreign minister
# national bank ukraine
# mr kenny
# national bank
# bank ukraine
#
# Concept 85:
# march 20
# al bab
# pic twitter
# st patrick
# kara murza
# high school
# new zealand
# human rights
# mr kenny
# foreign ministry
#
# Concept 86:
# human rights
# le pen
# scott pruitt
# emergency spillway
# human rights watch
# rights watch
# kara murza
# february tass
# attorney general
# border libya
#
# Concept 87:
# climate change
# year old
# joint economic
# human rights
# spokesman dmitry peskov
# spokesman dmitry
# dmitry peskov
# mr osborne
# mr bailey
# abc news
#
# Concept 88:
# south sudan
# south africa
# nuclear weapons
# north korea
# year old
# margin error
# huffpost yougov
# world cup
# mr noonan
# emergency spillway
#
# Concept 89:
# federal security service
# al qaeda
# federal security
# russia federal security
# russia federal security service
# security service
# kara murza
# russia federal
# bbc trending
# barack obama
#
# Concept 90:
# kara murza
# mr bailey
# foreign ministry
# ministry said
# bbc co
# bbc co uk
# co uk
# fox news
# foreign ministry said
# trump said
#
# Concept 91:
# pic twitter
# european union
# south sudan
# trump administration
# fox news
# mr bailey
# mulvaney said
# kim jong
# body shop
# credit rating
#
# Concept 92:
# world cup
# standing rock
# sioux tribe
# st petersburg
# black men
# rock sioux
# standing rock sioux
# national insurance
# confederations cup
# rock sioux tribe
#
# Concept 93:
# climate change
# mr sessions
# mr trump
# abc news
# stand ground
# credit rating
# https co
# moscow march
# transgender students
# national insurance
#
# Concept 94:
# press service
# saudi arabia
# service said
# us president
# new year
# world cup
# last seen
# press service said
# told tass
# donald trump
#
# Concept 95:
# northern ireland
# saudi arabia
# kara murza
# march 20
# john god
# st john god
# sesame street
# security service
# federal security
# federal security service
#
# Concept 96:
# body shop
# pic twitter
# al bab
# central bank
# eonstor gs
# asylum seekers
# mrs may
# water charges
# minister said
# northern syria
#
# Concept 97:
# ms mclaughlin
# south sudan
# mr trump
# moscow march
# north korea
# far right
# scott pruitt
# told tass
# chinese brands
# march 20
#
# Concept 98:
# new zealand
# climate change
# secretary general
# st petersburg
# https co
# supreme court
# world cup
# free trade
# ms shortall
# said statement
#
# Concept 99:
# march 20
# natural gas
# scott pruitt
# mr sessions
# planned parenthood
# vladimir putin
# climate change
# world cup
# mr bailey
# power plant

# %% [markdown]
# From the LSA, I was able to get a quick snapshot at the most significant concepts across the entire corpus of news articles. These articles are not based on one topic, rather are random as seen above some may involve entertainment/celebrity news while others state of national affairs and politics. For this model, I'm mainly interested in those articles which can potentially carry a positive or negative bias politically in some way. I am not at all concerned with sports, entertainment, or the latest viral trend on youtube (unless it happens to be polically related!).
#
# I will implement K-means clustering on the titles of the articles to see if I can classify/label them into categories based on their topic. After, I can then disregard the non-relevant articles and begin work on the bias classifier.

# %%
titles = df['title']

# %%
print(titles)
# Out:
# 0       Betsy DeVos Confirmed as Education Secretary, ...
# 1       Melania Trump Says White House Could Mean Mill...
# 2       As Trump Fears Fraud, GOP Eliminates Election ...
# 3       Appeals Court to Decide on Challenge to Trump'...
# 4       At Least 4 Tornadoes Reported in Southeast Lou...
# 5       Mother of Backpacker Slain in Australia Critic...
# 6       Trump's Labor Secretary Pick Andrew Puzder Adm...
# 7                Iran's Top Leader Mocks 'Newcomer' Trump
# 8       EU to Britain: Pay Up for What You Ordered Bef...
# 9       Multi-State Manhunt in Southeast Intensifies f...
# 10      Flu Takes a Toll in NYC With 4 Children Report...
# 11      Romania Protests Endure as President Says Coun...
# 12      Hillary Clinton Releases Video Statement: 'Fut...
# 13      Homeland Security Secretary John Kelly Defends...
# 14      2 Other Times Kellyanne Conway Referred to Bow...
# 15      Trump Says 'Very Dishonest Press Does Not Want...
# 16      Tom Brady Says Wife Gisele Bundchen Wants Him ...
# 17      Texas Rangers to Help Search for Tom Brady's S...
# 18      Putin Not a Friend, Poisoned Russian Activist'...
# 19      Dept. of Justice Cites 'National Security' in ...
# 20      Betsy DeVos confirmed as education secretary; ...
# 21                             Trump watch: Live coverage
# 22           A vote for DeVos is a vote for resegregation
# 23      Trump 'shows true face of US,' says Iran's Sup...
# 24           Al Qaeda leader mocks Trump after Yemen raid
# 25      Trump teeing up a softer diplomatic approach w...
# 26      Journalists call out White House claims on ter...
# 27      Trump travel ban oral arguments: what you need...
# 28      People appalled by corruption bill, Romanian P...
# 29      Barack Obama's kitesurfing adventure with Rich...
#                               ...
# 3794    Nigeria summons Indian ambassador over student...
# 3795    Subscribe to our new podcast, Al Jazeera Out Loud
# 3796    Al Jazeera reporter spends 100th day in Egypti...
# 3797            Israel: The house of hate Stanley L Cohen
# 3798                       Infographic: What is land day?
# 3799    British government takes next steps towards Br...
# 3800                                                  NaN
# 3801                                                  NaN
# 3802    The Gambia's missing sons and daughters Hamza ...
# 3803                                     India's Ladycops
# 3804    Welsh helicopter crash victims were members of...
# 3805               Clarity from garda¨ª on bonus payments
# 3806    Brexit secretary denies threat over security c...
# 3807     Boy who suffered injuries at birth awarded €1.5m
# 3808              South Korea's ousted president arrested
# 3809    SDLP leader hopeful NI talks will resume next ...
# 3810               Appeal for woman missing from Kilkenny
# 3811          Kim Jong Nam's body released to North Korea
# 3812     Dublin girl gets magical wonderland wish granted
# 3813    'Neither did Jesus please everyone' - Ronaldo ...
# 3814      Grenoble lifts suspension against rugby players
# 3815    PAC chair says he was pressured to limit Proje...
# 3816    Funeral of Danielle McLaughlin takes place in ...
# 3817    High Court endorses Ian Bailey European Arrest...
# 3818    Bus ?ireann warns rural school transport payme...
# 3819    12 applications for representation at Disclosu...
# 3820    Conditions preventing attempts to lift Rescue ...
# 3821    Children in Northern Ireland eating treble rec...
# 3822    Call for United Nations disabilities conventio...
# 3823    Carrickmines victims died of carbon monoxide p...
# Name: title, dtype: object

# %%
# Cast to string type, and lowercase all chars
titles = titles.astype(str)
titles = [x.lower() for x in titles]

# %%
# Define the vectorizer model for titles (K-means prep)
vectorizer = TfidfVectorizer(stop_words=stopset, use_idf=True, ngram_range=(2, 4),smooth_idf=True)

# Fit the corpus data
X = vectorizer.fit_transform(titles)

# %%
titles[0]
# Out:
# 'betsy devos confirmed as education secretary, with pence casting historic tie-breaking vote'

# %%
print(X[0])
# Out:
#   (0, 5108)	0.173227040217
#   (0, 12671)	0.189327738927
#   (0, 9708)	0.189327738927
#   (0, 14274)	0.173227040217
#   (0, 41044)	0.198746043907
#   (0, 33399)	0.198746043907
#   (0, 7465)	0.198746043907
#   (0, 21109)	0.189327738927
#   (0, 46737)	0.189327738927
#   (0, 6184)	0.189327738927
#   (0, 5109)	0.189327738927
#   (0, 12672)	0.189327738927
#   (0, 9709)	0.189327738927
#   (0, 14279)	0.198746043907
#   (0, 41045)	0.198746043907
#   (0, 33400)	0.198746043907
#   (0, 7466)	0.198746043907
#   (0, 21110)	0.189327738927
#   (0, 46738)	0.189327738927
#   (0, 5110)	0.189327738927
#   (0, 12673)	0.189327738927
#   (0, 9710)	0.198746043907
#   (0, 14280)	0.198746043907
#   (0, 41046)	0.198746043907
#   (0, 33401)	0.198746043907
#   (0, 7467)	0.198746043907
#   (0, 21111)	0.189327738927

# %%
def find_k (X, k_range, sample_percent=1):
    """
    k_range: a list of possible k values
    X, the data we're clustering on
    """
    from sklearn.cluster import KMeans
    import matplotlib.pyplot as plt
    import numpy as np
    from scipy.spatial.distance import cdist
    from sklearn.metrics import pairwise_distances

    N = X.shape[0]
    sampleSize = X.shape[0] * sample_percent

    if sampleSize > 0:
        index = np.arange(np.shape(X)[0])
        np.random.shuffle(index)
        X =  X[index, :]


    mean_distortions=[]
    for k in k_range:
        #cluster using k, then calculate the mean distortion (average distance to closest centroid)
        kmeans_model = KMeans(n_clusters=k, init='k-means++', n_jobs=-1).fit(X)
        mean_distortions.append(sum(np.min(pairwise_distances(X, kmeans_model.cluster_centers_,
                                                              metric='euclidean'),axis=1)) / X.shape[0])


    #visualize results
    plt.plot(k_range, mean_distortions)
    plt.xlabel("K Value")
    plt.ylabel("Mean Distortion")
    plt.title("Elbow Graph for Mean Distortion per K")
    plt.show()

# %%
df.columns
# Out:
# Index(['article_id', 'publish_date', 'article_source_link', 'title',
#        'subtitle', 'text'],
#       dtype='object')

# %%
df.article_source_link
# Out:
# 0       http://abcnews.go.com/Politics/pence-break-tie...
# 1       http://abcnews.go.com/Politics/wireStory/melan...
# 2       http://abcnews.go.com/Politics/wireStory/trump...
# 3       http://abcnews.go.com/Politics/appeals-court-d...
# 4       http://abcnews.go.com/US/23-states-winter-weat...
# 5       http://abcnews.go.com/International/wireStory/...
# 6       http://abcnews.go.com/Politics/trumps-labor-se...
# 7       http://abcnews.go.com/International/wireStory/...
# 8       http://abcnews.go.com/International/wireStory/...
# 9       http://abcnews.go.com/US/multi-state-manhunt-s...
# 10      http://abcnews.go.com/Health/flu-takes-toll-ny...
# 11      http://abcnews.go.com/International/wireStory/...
# 12      http://abcnews.go.com/US/wireStory/hillary-cli...
# 13      http://abcnews.go.com/Politics/homeland-securi...
# 14      http://abcnews.go.com/Politics/times-kellyanne...
# 15      http://abcnews.go.com/Politics/trump-dishonest...
# 16      http://abcnews.go.com/Entertainment/tom-brady-...
# 17      http://abcnews.go.com/Sports/tom-brady-missing...
# 18      http://abcnews.go.com/International/putin-frie...
# 19      http://abcnews.go.com/Politics/dept-justice-ca...
# 20      http://www.cnn.com/2017/02/07/politics/betsy-d...
# 21      http://www.cnn.com/2017/02/07/politics/trump-w...
# 22      http://www.cnn.com/2017/02/05/opinions/devos-r...
# 23      http://www.cnn.com/2017/02/07/politics/iran-kh...
# 24      http://www.cnn.com/2017/02/07/politics/yemen-r...
# 25      http://www.cnn.com/2017/02/07/politics/trump-j...
# 26      http://www.cnn.com/2017/02/07/politics/white-h...
# 27      http://www.cnn.com/2017/02/07/politics/trump-t...
# 28      http://www.cnn.com/2017/02/07/europe/romanian-...
# 29      http://www.cnn.com/2017/02/07/politics/barack-...
#                               ...
# 3794    http://www.aljazeera.com/news/2017/03/nigeria-...
# 3795    http://www.aljazeera.com/podcasts/aljazeera-ou...
# 3796    http://www.aljazeera.com/news/2017/03/al-jazee...
# 3797    http://www.aljazeera.com/indepth/features/2017...
# 3798    http://www.aljazeera.com/indepth/interactive/2...
# 3799    http://www.aljazeera.com/news/2017/03/british-...
# 3800    http://www.aljazeera.com/indepth/opinion/2017/...
# 3801    http://www.aljazeera.com/indepth/opinion/2017/...
# 3802    http://www.aljazeera.com/indepth/features/2017...
# 3803    http://www.aljazeera.com/programmes/specialser...
# 3804    http://www.rte.ie/news/2017/0330/863683-search...
# 3805    http://www.rte.ie/news/ireland/2017/0330/86367...
# 3806    http://www.rte.ie/news/brexit/2017/0330/863704...
# 3807    http://www.rte.ie/news/ireland/2017/0330/86396...
# 3808    http://www.rte.ie/news/world/2017/0330/863957-...
# 3809    http://www.rte.ie/news/ireland/2017/0330/86396...
# 3810    http://www.rte.ie/news/leinster/2017/0330/8639...
# 3811    http://www.rte.ie/news/world/2017/0330/863876-...
# 3812    http://www.rte.ie/news/dublin/2017/0330/863867...
# 3813    http://www.rte.ie/sport/soccer/2017/0330/86379...
# 3814    http://www.rte.ie/news/world/2017/0330/863899-...
# 3815    http://www.rte.ie/news/politics/2017/0330/8637...
# 3816    http://www.rte.ie/news/ulster/2017/0330/863703...
# 3817    http://www.rte.ie/news/courts/2017/0330/863743...
# 3818    http://www.rte.ie/news/2017/0330/863797-bus-ei...
# 3819    http://www.rte.ie/news/ireland/2017/0330/86367...
# 3820    http://www.rte.ie/news/connacht/2017/0330/8638...
# 3821    http://www.rte.ie/news/ulster/2017/0330/863787...
# 3822    http://www.rte.ie/news/ireland/2017/0330/86391...
# 3823    http://www.rte.ie/news/ireland/2017/0330/86388...
# Name: article_source_link, dtype: object

# %%
# Cleanning the Article URLs, only want the domains for classifying between news organizations.
i = 0
from urllib.parse import urlparse
for url in df.article_source_link:
    domain = url.split("//")[-1].split("/")[0]
    df.article_source_link[i] = domain
    i+=1
# Out:
# /Users/jsche4/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.article_source_link.value_counts()
# Out:
# www.aljazeera.com           559
# tass.com                    485
# abcnews.go.com              474
# www.rte.ie                  443
# www.dw.com                  436
# www.huffingtonpost.com      436
# europe.chinadaily.com.cn    360
# www.bbc.co.uk               355
# www.cnn.com                 276
# Name: article_source_link, dtype: int64

# %%
# Definitely could have done this more efficiently, but now I want only the news organization names.
# Labeling as domain_countrycode (SA=Saudi Arabia, RU=Russia, US=United States, IE=Ireland, GE=Germany, CN=China, UK=United Kingdom)
i = 0
from urllib.parse import urlparse
for url in df.article_source_link:
    if (url == 'www.aljazeera.com'):
        df.article_source_link[i] = 'ALJAZEERA_SA'
    if (url == 'tass.com'):
        df.article_source_link[i] = 'TASS_RU'
    if (url == 'abcnews.go.com'):
        df.article_source_link[i] = 'ABC_US'
    if (url == 'www.rte.ie'):
        df.article_source_link[i] = 'RTE_IE'
    if (url == 'www.dw.com'):
        df.article_source_link[i] = 'DW_GE'
    if (url == 'www.huffingtonpost.com'):
        df.article_source_link[i] = 'HUFFINGTONPOST_US'
    if (url == 'europe.chinadaily.com.cn'):
        df.article_source_link[i] = 'CHINADAILY_CN'
    if (url == 'www.bbc.co.uk'):
        df.article_source_link[i] = 'BBC_UK'
    if (url == 'www.cnn.com'):
        df.article_source_link[i] = 'CNN_US'
    i+=1
# Out:
# /Users/jsche4/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jsche4/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jsche4/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jsche4/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jsche4/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jsche4/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jsche4/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jsche4/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jsche4/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df['article_source_link'].value_counts()
# Out:
# ALJAZEERA_SA         559
# TASS_RU              485
# ABC_US               474
# RTE_IE               443
# HUFFINGTONPOST_US    436
# DW_GE                436
# CHINADAILY_CN        360
# BBC_UK               355
# CNN_US               276
# Name: article_source_link, dtype: int64

# %%
df.head()
# Out:
#    article_id publish_date article_source_link  \
# 0           1       2/7/17              ABC_US
# 1           2       2/7/17              ABC_US
# 2           3       2/7/17              ABC_US
# 3           4       2/7/17              ABC_US
# 4           5       2/7/17              ABC_US
#
#                                                title subtitle  \
# 0  Betsy DeVos Confirmed as Education Secretary, ...      NaN
# 1  Melania Trump Says White House Could Mean Mill...      NaN
# 2  As Trump Fears Fraud, GOP Eliminates Election ...      NaN
# 3  Appeals Court to Decide on Challenge to Trump'...      NaN
# 4  At Least 4 Tornadoes Reported in Southeast Lou...      NaN
#
#                                                 text
# 0  Michigan billionaire education activist Betsy ...
# 1  First lady Melania Trump has said little about...
# 2  A House committee voted on Tuesday to eliminat...
# 3  This afternoon, three federal judges from the ...
# 4  At least four tornadoes touched down in Louisi...

# %%
# More than half of our subtitle feature values are missing.
df.subtitle.isnull().value_counts()
# Out:
# False    2337
# True     1487
# Name: subtitle, dtype: int64

# %%
# For the purpose of this analysis, I will not be using the dates (at least yet), I will pop and pickle that feature.
from sklearn.externals import joblib
dates = df.pop('publish_date')
joblib.dump(dates, 'dates_col.pkl')
# Out:
# ['dates_col.pkl']

# %%
# The article_id number appears to be sequential and meaningless. I will just drop that column entirely.
df.drop('article_id',axis=1,inplace=True)

# %%
# I'm still undecided how I plan to approach/use the subtitle feature yet.
# For now I will mark all the missing values and leave it in tact.
df['subtitle'].fillna("Missing", inplace=True)

# %%
# Finally, I will checkpoint here by saving my prepped df to pickle.
joblib.dump(df, 'df_prepped.pkl')
# Out:
# ['df_prepped.pkl']
